# %% [markdown]
# ### This runs a couple of tests on the bootstrap function. The first plots use a simple Gaussian distriubution, while the last two have skewed the Gaussian to the right.

# %%
run ~/anaconda/GitHub/lrg-project/lrg_plot_functions.py

# %%
import numpy as np
from scipy.stats import skewnorm
import matplotlib.pyplot as plt

# %%
mu, sigma = 5.0, 1.0
s = np.random.normal(mu, sigma, 1000)

plt.hist(s,bins=50)
plt.show()

# %%
boot_med_plot(1000, 0.68, np.median, s)
# Out:
# The median of Nsat: 4.94206248772
# The median of bootmed: 4.94206248772
# Low 68% confidence interval: 4.90643914296
# High 68% confidence interval: 4.97052376001

# %%
from scipy.stats import skewnorm

# %%
a = 4
# mean, var, skew, kurt = skewnorm.stats(a, moments='mvsk')
r = skewnorm.rvs(a, size=1000)

plt.hist(r,bins=50)
plt.show()

# %%
boot_med_plot(100000, 0.68, np.median, r)
# Out:
# The median of Nsat: 0.708820641618
# The median of bootmed: 0.708820641618
# Low 68% confidence interval: 0.669372697626
# High 68% confidence interval: 0.721936728078
