# %% [markdown]
# ### This notebook contains plots examining what relationship exists, if any, between LRG mass and the number of satellites it possesses.
#
# #### Mindy Townsned
# #### Last edit: 24 July 2018

# %%
run ~/anaconda/GitHub/lrg-project/statSub_Mark2.py
# Out:
# end data parsing
# end CosmoCalc
# end surface density calculation
# end near neighbor calculation
# local nn example: 2412
# local nn example: 1470
# local nn example: 2621
# local nn ind example: 2412
# local nn ind example: 1470
# local nn ind example: 2621
# (1151, 10, 10)
# (1151,)
# end background galaxy calculation
# 1151
# end satellite galaxy calculation
# end of program

# %%
sumsat, sumsat1z, sumsat2z, sumsat3z, sumsat4z, sumsat5z, sumsat6z, sumsat7z, sumsat1r, sumsat2r, sumsat3r, sumsat4r, sumsat5r, sumsat6r, sumsat7r, sumsat1g, sumsat2g, sumsat3g, sumsat4g, sumsat5g, sumsat6g, sumsat7g, sumsat8g, sumsat1_zmag, sumsat2_zmag, sumsat3_zmag, sumsat4_zmag, sumsat5_zmag, sumsat6_zmag, sumsat7_zmag = sumNsat(Nsat, z_LRG, rmag_LRG, gmag_LRG, zmag_LRG)

# %%
sumnear, sumnear1z, sumnear2z, sumnear3z, sumnear4z, sumnear5z, sumnear6z, sumnear7z, sumnear1r, sumnear2r, sumnear3r, sumnear4r, sumnear5r, sumnear6r, sumnear7r, sumnear1g, sumnear2g, sumnear3g, sumnear4g, sumnear5g, sumnear6g, sumnear7g, sumnear8g, sumnear1_zmag, sumnear2_zmag, sumnear3_zmag, sumnear4_zmag, sumnear5_zmag, sumnear6_zmag, sumnear7_zmag = sumNN(near, z_LRG, rmag_LRG, gmag_LRG, zmag_LRG)

# %%
# Read in data
data = open('/Users/mtownsend/anaconda/Github/lrg-project/lrg_project_masses2.txt', 'r') 
lines = data.readlines()[23:] # start reading at line 24

data.close() 

# Create array
mass_mod = []
z_mod = []

# Append data to the array
for line in lines:
    p = line.split()
    z_mod.append(float(p[0]))
    mass_mod.append(float(p[2]))
    
# print(z_mod)
# print(mass_mod)

# %%
# gives index for model redshifts in LRG order

temp = []
for i in range(len(z_LRG)):
    temp.append(min(range(len(z_mod)), key=lambda j:abs(z_mod[j] - z_LRG[i])))
    
# gives model masses in LRG order

mass_LRG = []
for i in range(len(temp)):
    mass_LRG.append(mass_mod[int(temp[i])])
    
print(type(mass_LRG[0]))
mass_LRG = np.array(mass_LRG)
# Out:
# <class 'float'>

# %%
mass_LRG = np.asarray(mass_LRG)

mass1z = mass_LRG[np.where(z_LRG < 0.2)]
mass2z = mass_LRG[np.where((z_LRG >= 0.2) & (0.3 > z_LRG))]
mass3z = mass_LRG[np.where((z_LRG >= 0.3) & (0.4 > z_LRG))]
mass4z = mass_LRG[np.where((z_LRG >= 0.4) & (0.5 > z_LRG))]
mass5z = mass_LRG[np.where((z_LRG >= 0.5) & (0.6 > z_LRG))]
mass6z = mass_LRG[np.where((z_LRG >= 0.6) & (0.7 > z_LRG))]
mass7z = mass_LRG[np.where(z_LRG >= 0.7)]

# %%
plt.rcParams["figure.figsize"] = [10,8]
plt.title("Number of Satellites vs. LRG Mass", fontsize=15)
plt.scatter(mass1z, sumsat1z, s=3, color='royalblue', label='z_LRG < 0.2')
plt.scatter(mass2z, sumsat2z, s=3, color='rebeccapurple', label='0.2 < z_LRG < 0.3')
plt.scatter(mass3z, sumsat3z, s=3, color='seagreen', label='0.3 < z_LRG < 0.4')
plt.scatter(mass4z, sumsat4z, s=3, color='turquoise', label='0.4 < z_LRG < 0.5')
plt.scatter(mass5z, sumsat5z, s=3, color='sandybrown', label='0.5 < z_LRG < 0.6')
plt.scatter(mass6z, sumsat6z, s=3, color='orangered', label='0.6 < z_LRG < 0.7')
plt.scatter(mass7z, sumsat7z, s=3, color='grey', label='z_LRG > 0.7')
plt.xlabel(r'$LRG$ $Mass$', fontsize = 12)
plt.ylabel(r'$Number$ $of$ $Satellites$', fontsize = 12)
plt.legend(loc='upper right')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10,8]
plt.title("Number of Near Neighbors vs. LRG Mass", fontsize=15)
plt.scatter(mass1z, sumnear1z, s=3, color='royalblue', label='z_LRG < 0.2')
plt.scatter(mass2z, sumnear2z, s=3, color='rebeccapurple', label='0.2 < z_LRG < 0.3')
plt.scatter(mass3z, sumnear3z, s=3, color='seagreen', label='0.3 < z_LRG < 0.4')
plt.scatter(mass4z, sumnear4z, s=3, color='turquoise', label='0.4 < z_LRG < 0.5')
plt.scatter(mass5z, sumnear5z, s=3, color='sandybrown', label='0.5 < z_LRG < 0.6')
plt.scatter(mass6z, sumnear6z, s=3, color='orangered', label='0.6 < z_LRG < 0.7')
plt.scatter(mass7z, sumnear7z, s=3, color='grey', label='z_LRG > 0.7')
plt.xlabel(r'$LRG$ $Mass$', fontsize = 12)
plt.ylabel(r'$Number$ $of$ $Near$ $Neighbors$', fontsize = 12)
plt.legend(loc='upper right')
plt.show()

# %%
# Divvy up by LRG mass slice

Nsat1mass = Nsat[np.where((mass_LRG >= 1.40e11) & (1.41e11 > mass_LRG))]
print(len(Nsat1mass))

sumsat1mass = []
for i in range(len(Nsat1mass)):
    sumsat1mass.append(np.sum(Nsat1mass[i]))

# 0.2 <= z < 0.3
Nsat2mass = Nsat[np.where((mass_LRG >= 1.41e11) & (1.42e11 > mass_LRG))]
print(len(Nsat2mass))

sumsat2mass = []
for i in range(len(Nsat2mass)):
    sumsat2mass.append(np.sum(Nsat2mass[i]))

# 0.3 <= z < 0.4
Nsat3mass = Nsat[np.where((mass_LRG >= 1.42e11) & (1.43e11 > mass_LRG))]
print(len(Nsat3mass))

sumsat3mass = []
for i in range(len(Nsat3mass)):
    sumsat3mass.append(np.sum(Nsat3mass[i]))

# 0.4 <= z < 0.5
Nsat4mass = Nsat[np.where((mass_LRG >= 1.43e11) & (1.44e11 > mass_LRG))]
print(len(Nsat4mass))

sumsat4mass = []
for i in range(len(Nsat4mass)):
    sumsat4mass.append(np.sum(Nsat4mass[i]))

# 0.5 <= z < 0.6
Nsat5mass = Nsat[np.where((mass_LRG >= 1.44e11) & (1.45e11 > mass_LRG))]
print(len(Nsat5mass))

sumsat5mass = []
for i in range(len(Nsat5mass)):
    sumsat5mass.append(np.sum(Nsat5mass[i]))

# 0.6 <= z < 0.7
Nsat6mass = Nsat[np.where((mass_LRG >= 1.45e11) & (1.46e11 > mass_LRG))]
print(len(Nsat6mass))

sumsat6mass = []
for i in range(len(Nsat6mass)):
    sumsat6mass.append(np.sum(Nsat6mass[i]))

# z >= 0.7
Nsat7mass = Nsat[np.where(mass_LRG >= 1.46e11)]
print(len(Nsat7mass))

sumsat7mass = []
for i in range(len(Nsat7mass)):
    sumsat7mass.append(np.sum(Nsat7mass[i]))
# Out:
# 23
# 170
# 220
# 413
# 272
# 48
# 5

# %%
import numpy as np

med_mass1 = np.median(sumsat1mass)
med_mass2 = np.median(sumsat2mass)
med_mass3 = np.median(sumsat3mass)
med_mass4 = np.median(sumsat4mass)
med_mass5 = np.median(sumsat5mass)
med_mass6 = np.median(sumsat6mass)
med_mass7 = np.median(sumsat7mass)

print("Median number of satellites for 1.40e11 <= mass < 1.41e11: ", med_mass1)
print("Median number of satellites for 1.41e11 <= mass < 1.42e11: ", med_mass2)
print("Median number of satellites for 1.42e11 <= mass < 1.43e11: ", med_mass3)
print("Median number of satellites for 1.43e11 <= mass < 1.44e11: ", med_mass4)
print("Median number of satellites for 1.44e11 <= mass < 1.45e11: ", med_mass5)
print("Median number of satellites for 1.45e11 <= mass < 1.46e11: ", med_mass6)
print("Median number of satellites for mass >= 1.46e11: ", med_mass7)
# Out:
# Median number of satellites for 1.40e11 <= mass < 1.41e11:  24.92
# Median number of satellites for 1.41e11 <= mass < 1.42e11:  13.17
# Median number of satellites for 1.42e11 <= mass < 1.43e11:  12.26
# Median number of satellites for 1.43e11 <= mass < 1.44e11:  9.28
# Median number of satellites for 1.44e11 <= mass < 1.45e11:  8.22
# Median number of satellites for 1.45e11 <= mass < 1.46e11:  4.755
# Median number of satellites for mass >= 1.46e11:  16.88

# %%
# plt.title("Histogram of the Number of Satellite Galaxies at Different LRG Mass Bins")
# plt.hist(sumsat1mass, bins=25, alpha=0.5, label='1.40e11 <= mass < 1.41e11')
# plt.hist(sumsat2mass, bins=25, alpha=0.5, label='1.41e11 <= mass < 1.42e11')
# plt.hist(sumsat3mass, bins=25, alpha=0.5, label='1.42e11 <= mass < 1.43e11')
# plt.hist(sumsat4mass, bins=25, alpha=0.5, label='1.43e11 <= mass < 1.44e11')
# plt.hist(sumsat5mass, bins=25, alpha=0.5, label='1.44e11 <= mass < 1.45e11')
# plt.hist(sumsat6mass, bins=25, alpha=0.5, label='1.45e11 <= mass < 1.46e11')
# plt.hist(sumsat7mass, bins=25, alpha=0.5, label='mass >= 1.46e11')
# plt.xlabel(r'$satellites$')
# plt.ylabel(r'$counts$')
# plt.legend(loc='upper right')
# plt.show()

f, axarr = plt.subplots(4, 2, figsize=(15,15))
f.suptitle("Histogram of the Number of Satellite Galaxies at Different LRG Mass Bins", fontsize=15, y=0.9)

axarr[0, 0].hist(sumsat1mass, bins=25, color='lightblue', label='1.40e11 <= mass < 1.41e11')
axarr[0, 0].legend(loc='upper right')
# 	axarr[0, 0].axvline(linewidth=1, color='black')

axarr[0, 1].hist(sumsat2mass, bins=25, color='orange',label='1.41e11 <= mass < 1.42e11')
axarr[0, 1].legend(loc='upper right')
# 	axarr[0, 1].axvline(linewidth=1, color='black')

axarr[1, 0].hist(sumsat3mass, bins=25, color='green', label='1.42e11 <= mass < 1.43e11')
axarr[1, 0].legend(loc='upper right')
# 	axarr[1, 0].axvline(linewidth=1, color='black')

axarr[1, 1].hist(sumsat4mass, bins=25, color='red', label='1.43e11 <= mass < 1.44e11')
axarr[1, 1].legend(loc='upper right')
# 	axarr[1, 1].axvline(linewidth=1, color='black')

axarr[2,0].hist(sumsat5mass, bins=25, color='purple', label='1.44e11 <= mass < 1.45e11')
axarr[2,0].legend(loc='upper right')
# 	axarr[2,0].axvline(linewidth=1, color='black')

axarr[2,1].hist(sumsat6mass, bins=25, color='brown', label='1.45e11 <= mass < 1.46e11')
axarr[2,1].legend(loc='upper right')
# 	axarr[2,1].axvline(linewidth=1, color='black')

axarr[3,0].hist(sumsat7mass, bins=25, color='pink', label='mass >= 1.46e11')
axarr[3,0].legend(loc='upper right')
# 	axarr[3,0].axvline(linewidth=1, color='black')

f.delaxes(axarr[3,1])
    # Fine-tune figure; make subplots farther from each other.
f.subplots_adjust(hspace=0.5)
    # f.subplots_adjust(wspace=0.5)

for ax in axarr.flat:
	ax.set(xlabel='satellites', ylabel='counts')

plt.show()

# %% [markdown]
# These histograms of satellites in bins of LRG mass indicate that for every mass slice LRGs can be expected to have satellites.

# %% [markdown]
# ### Bootstrap median for different mass bins

# %%
bootmed1mass_sat, lowconf1mass_sat, hiconf1mass_sat = boot_med_plot(1000, 0.68, np.median, sumsat1mass)
plt.show()
# Out:
# The median of Nsat: 24.92
# The median of bootmed: 24.92
# Low 68% confidence interval: 23.49
# High 68% confidence interval: 28.07

# %%
bootmed2mass_sat, lowconf2mass_sat, hiconf2mass_sat = boot_med_plot(1000, 0.68, np.median, sumsat2mass)
plt.show()
# Out:
# The median of Nsat: 13.17
# The median of bootmed: 12.94
# Low 68% confidence interval: 11.01
# High 68% confidence interval: 17.25

# %%
bootmed3mass_sat, lowconf3mass_sat, hiconf3mass_sat = boot_med_plot(1000, 0.68, np.median, sumsat3mass)
plt.show()
# Out:
# The median of Nsat: 12.26
# The median of bootmed: 12.17
# Low 68% confidence interval: 10.665
# High 68% confidence interval: 13.11

# %%
bootmed4mass_sat, lowconf4mass_sat, hiconf4mass_sat = boot_med_plot(1000, 0.68, np.median, sumsat4mass)
plt.show()
# Out:
# The median of Nsat: 9.28
# The median of bootmed: 9.27
# Low 68% confidence interval: 8.46
# High 68% confidence interval: 10.3

# %%
bootmed5mass_sat, lowconf5mass_sat, hiconf5mass_sat = boot_med_plot(1000, 0.68, np.median, sumsat5mass)
plt.show()
# Out:
# The median of Nsat: 8.22
# The median of bootmed: 8.22
# Low 68% confidence interval: 7.36
# High 68% confidence interval: 8.92

# %%
bootmed6mass_sat, lowconf6mass_sat, hiconf6mass_sat = boot_med_plot(1000, 0.68, np.median, sumsat6mass)
plt.show()
# Out:
# The median of Nsat: 4.755
# The median of bootmed: 4.755
# Low 68% confidence interval: 3.81
# High 68% confidence interval: 7.22

# %%
bootmed7mass_sat, lowconf7mass_sat, hiconf7mass_sat = boot_med_plot(1000, 0.68, np.median, sumsat7mass)
plt.show()
# Out:
# The median of Nsat: 16.88
# The median of bootmed: 16.88
# Low 68% confidence interval: -1.37
# High 68% confidence interval: 18.72

# %% [markdown]
# The last mass bin only has five sources, but otherwise the plot below indicates that there is a trend of fewer satellites with increasing mass. Which is a little suprising to me because I thought more massive galaxies would hold more satellite galaxies around it, but maybe they are so big because a bunch of its satellites have already fallen in.

# %%
median_array_mass_sat = [bootmed1mass_sat, bootmed2mass_sat, bootmed3mass_sat, bootmed4mass_sat, bootmed5mass_sat, bootmed6mass_sat, bootmed7mass_sat]
mass_array_sat = [1, 2, 3, 4, 5, 6, 7] # 1 is the lowest mass bin and 7 is the highest mass bin
upper_error_mass_sat = [hiconf1mass_sat - bootmed1mass_sat, hiconf2mass_sat - bootmed2mass_sat, hiconf3mass_sat - bootmed3mass_sat, hiconf4mass_sat - bootmed4mass_sat, hiconf5mass_sat - bootmed5mass_sat, hiconf6mass_sat - bootmed6mass_sat, hiconf7mass_sat - bootmed7mass_sat]
lower_error_mass_sat = [bootmed1mass_sat - lowconf1mass_sat, bootmed2mass_sat - lowconf2mass_sat, bootmed3mass_sat - lowconf3mass_sat, bootmed4mass_sat - lowconf4mass_sat, bootmed5mass_sat - lowconf5mass_sat, bootmed6mass_sat - lowconf6mass_sat, bootmed7mass_sat - lowconf7mass_sat]
asymmetric_error_mass_sat = [lower_error_mass_sat, upper_error_mass_sat]

plt.figure()
plt.title("Median Number of Satellites vs. Mass bin")
plt.xlabel(r'$mass$ $bin$')
plt.ylabel(r'$median$ $number$ $of$ $satellites$')
plt.scatter(mass_array_sat, median_array_mass_sat, c='blue')
plt.errorbar(mass_array_sat, median_array_mass_sat, yerr = asymmetric_error_mass_sat)
plt.show()

# %%
import operator
max_index, max_value = max(enumerate(sumsat), key=operator.itemgetter(1))
min_index, min_value = min(enumerate(sumsat), key=operator.itemgetter(1))
print(max_index)
print(max_value)
print(min_index)
print(min_value)
# Out:
# 327
# 143.81
# 82
# -65.25

# %%
print(ra_LRG[535])
print(dec_LRG[535])

print(ra_LRG[117])
print(dec_LRG[117])
# Out:
# 242.625868989
# 7.56479443502
# 241.25490129
# 8.81906850383

# %%
plt.scatter(ra_BKG, dec_BKG, s=0.1, color='blue', marker='o')
plt.scatter(ra_LRG[535], dec_LRG[535], s=50, color='hotpink')
plt.scatter(ra_LRG[117], dec_LRG[117], s=50, color='lime')
plt.scatter(ra_LRG, dec_LRG, s=1, color='red', marker='+')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10,8]
plt.title("LRG Redshift vs. LRG Mass", fontsize=15)
plt.scatter(mass_LRG[np.where(z_LRG < 0.2)], z_LRG[np.where(z_LRG < 0.2)], s=2, color='royalblue', label='z_LRG < 0.2')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.2) & (0.3 > z_LRG))], z_LRG[np.where((z_LRG >= 0.2) & (0.3 > z_LRG))], s=2, color='rebeccapurple', label='0.2 < z_LRG < 0.3')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.3) & (0.4 > z_LRG))], z_LRG[np.where((z_LRG >= 0.3) & (0.4 > z_LRG))], s=2, color='seagreen', label='0.3 < z_LRG < 0.4')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.4) & (0.5 > z_LRG))], z_LRG[np.where((z_LRG >= 0.4) & (0.5 > z_LRG))], s=2, color='turquoise', label='0.4 < z_LRG < 0.5')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.5) & (0.6 > z_LRG))], z_LRG[np.where((z_LRG >= 0.5) & (0.6 > z_LRG))], s=2, color='sandybrown', label='0.5 < z_LRG < 0.6')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.6) & (0.7 > z_LRG))], z_LRG[np.where((z_LRG >= 0.6) & (0.7 > z_LRG))], s=2, color='orangered', label='0.6 < z_LRG < 0.7')
plt.scatter(mass_LRG[np.where(z_LRG >= 0.7)], z_LRG[np.where(z_LRG >= 0.7)], s=2, color='grey', label='z_LRG > 0.7')
plt.xlabel(r'$LRG$ $Mass$', fontsize = 12)
plt.ylabel(r'$LRG$ $Redshift$', fontsize = 12)
plt.legend(loc='lower right')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10,8]
plt.title("LRG r-mag vs. LRG Mass", fontsize=15)
plt.scatter(mass_LRG, rmag_LRG, s=2, color='firebrick')
plt.xlabel(r'$LRG$ $Mass$', fontsize = 12)
plt.ylabel(r'$LRG$ $rmag$', fontsize = 12)
plt.gca().invert_yaxis()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10,8]
plt.title("LRG rmag vs. LRG Mass", fontsize=15)
plt.scatter(mass_LRG[np.where(z_LRG < 0.2)], rmag_LRG[np.where(z_LRG < 0.2)], s=2, color='royalblue', label='z_LRG < 0.2')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.2) & (0.3 > z_LRG))], rmag_LRG[np.where((z_LRG >= 0.2) & (0.3 > z_LRG))], s=2, color='rebeccapurple', label='0.2 < z_LRG < 0.3')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.3) & (0.4 > z_LRG))], rmag_LRG[np.where((z_LRG >= 0.3) & (0.4 > z_LRG))], s=2, color='seagreen', label='0.3 < z_LRG < 0.4')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.4) & (0.5 > z_LRG))], rmag_LRG[np.where((z_LRG >= 0.4) & (0.5 > z_LRG))], s=2, color='turquoise', label='0.4 < z_LRG < 0.5')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.5) & (0.6 > z_LRG))], rmag_LRG[np.where((z_LRG >= 0.5) & (0.6 > z_LRG))], s=2, color='sandybrown', label='0.5 < z_LRG < 0.6')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.6) & (0.7 > z_LRG))], rmag_LRG[np.where((z_LRG >= 0.6) & (0.7 > z_LRG))], s=2, color='orangered', label='0.6 < z_LRG < 0.7')
plt.scatter(mass_LRG[np.where(z_LRG >= 0.7)], rmag_LRG[np.where(z_LRG >= 0.7)], s=2, color='grey', label='z_LRG > 0.7')
plt.xlabel(r'$LRG$ $Mass$', fontsize = 12)
plt.ylabel(r'$LRG$ $rmag$', fontsize = 12)
plt.gca().invert_yaxis()
plt.legend(loc='upper right')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10,8]
plt.title("LRG g-mag vs. LRG Mass", fontsize=15)
plt.scatter(mass_LRG, gmag_LRG, s=2, color='forestgreen')
plt.xlabel(r'$LRG$ $Mass$', fontsize = 12)
plt.ylabel(r'$LRG$ $gmag$', fontsize = 12)
plt.gca().invert_yaxis()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10,8]
plt.title("LRG gmag vs. LRG Mass", fontsize=15)
plt.scatter(mass_LRG[np.where(z_LRG < 0.2)], gmag_LRG[np.where(z_LRG < 0.2)], s=2, color='royalblue', label='z_LRG < 0.2')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.2) & (0.3 > z_LRG))], gmag_LRG[np.where((z_LRG >= 0.2) & (0.3 > z_LRG))], s=2, color='rebeccapurple', label='0.2 < z_LRG < 0.3')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.3) & (0.4 > z_LRG))], gmag_LRG[np.where((z_LRG >= 0.3) & (0.4 > z_LRG))], s=2, color='seagreen', label='0.3 < z_LRG < 0.4')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.4) & (0.5 > z_LRG))], gmag_LRG[np.where((z_LRG >= 0.4) & (0.5 > z_LRG))], s=2, color='turquoise', label='0.4 < z_LRG < 0.5')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.5) & (0.6 > z_LRG))], gmag_LRG[np.where((z_LRG >= 0.5) & (0.6 > z_LRG))], s=2, color='sandybrown', label='0.5 < z_LRG < 0.6')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.6) & (0.7 > z_LRG))], gmag_LRG[np.where((z_LRG >= 0.6) & (0.7 > z_LRG))], s=2, color='orangered', label='0.6 < z_LRG < 0.7')
plt.scatter(mass_LRG[np.where(z_LRG >= 0.7)], gmag_LRG[np.where(z_LRG >= 0.7)], s=2, color='grey', label='z_LRG > 0.7')
plt.xlabel(r'$LRG$ $Mass$', fontsize = 12)
plt.ylabel(r'$LRG$ $gmag$', fontsize = 12)
plt.gca().invert_yaxis()
plt.legend(loc='upper right')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10,8]
plt.title("LRG z-mag vs. LRG Mass", fontsize=15)
plt.scatter(mass_LRG, zmag_LRG, s=2, color='mediumblue')
plt.xlabel(r'$LRG$ $Mass$', fontsize = 12)
plt.ylabel(r'$LRG$ $zmag$', fontsize = 12)
plt.gca().invert_yaxis()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10,8]
plt.title("LRG zmag vs. LRG Mass", fontsize=15)
plt.scatter(mass_LRG[np.where(z_LRG < 0.2)], zmag_LRG[np.where(z_LRG < 0.2)], s=2, color='royalblue', label='z_LRG < 0.2')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.2) & (0.3 > z_LRG))], zmag_LRG[np.where((z_LRG >= 0.2) & (0.3 > z_LRG))], s=2, color='rebeccapurple', label='0.2 < z_LRG < 0.3')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.3) & (0.4 > z_LRG))], zmag_LRG[np.where((z_LRG >= 0.3) & (0.4 > z_LRG))], s=2, color='seagreen', label='0.3 < z_LRG < 0.4')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.4) & (0.5 > z_LRG))], zmag_LRG[np.where((z_LRG >= 0.4) & (0.5 > z_LRG))], s=2, color='turquoise', label='0.4 < z_LRG < 0.5')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.5) & (0.6 > z_LRG))], zmag_LRG[np.where((z_LRG >= 0.5) & (0.6 > z_LRG))], s=2, color='sandybrown', label='0.5 < z_LRG < 0.6')
plt.scatter(mass_LRG[np.where((z_LRG >= 0.6) & (0.7 > z_LRG))], zmag_LRG[np.where((z_LRG >= 0.6) & (0.7 > z_LRG))], s=2, color='orangered', label='0.6 < z_LRG < 0.7')
plt.scatter(mass_LRG[np.where(z_LRG >= 0.7)], zmag_LRG[np.where(z_LRG >= 0.7)], s=2, color='grey', label='z_LRG > 0.7')
plt.xlabel(r'$LRG$ $Mass$', fontsize = 12)
plt.ylabel(r'$LRG$ $zmag$', fontsize = 12)
plt.gca().invert_yaxis()
plt.legend(loc='upper right')
plt.show()
